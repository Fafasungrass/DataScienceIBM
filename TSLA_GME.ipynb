# %%
import yfinance as yf

# %%
tesla = yf.Ticker("TSLA")
print(tesla)
# Out:
# yfinance.Ticker object <TSLA>

# %%
tesla.info

# %%
tesla.history(period="max")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2023-05-15 00:00:00-04:00  167.660004  169.759995  164.550003  166.350006
# 2023-05-16 00:00:00-04:00  165.649994  169.520004  164.350006  166.520004
# 2023-05-17 00:00:00-04:00  168.410004  174.500000  167.190002  173.860001
# 2023-05-18 00:00:00-04:00  174.220001  177.059998  172.449997  176.889999
# 2023-05-19 00:00:00-04:00  177.169998  181.949997  176.320007  180.139999
#
#                               Volume  Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00  281494500        0.0           0.0
# 2010-06-30 00:00:00-04:00  257806500        0.0           0.0
# 2010-07-01 00:00:00-04:00  123282000        0.0           0.0
# 2010-07-02 00:00:00-04:00   77097000        0.0           0.0
# 2010-07-06 00:00:00-04:00  103003500        0.0           0.0
# ...                              ...        ...           ...
# 2023-05-15 00:00:00-04:00  105592500        0.0           0.0
# 2023-05-16 00:00:00-04:00   98288800        0.0           0.0
# 2023-05-17 00:00:00-04:00  125473600        0.0           0.0
# 2023-05-18 00:00:00-04:00  109520300        0.0           0.0
# 2023-05-19 00:00:00-04:00  134460894        0.0           0.0
#
# [3246 rows x 7 columns]

# %%
tesla_data = yf.download("TSLA")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tesla_data.reset_index(inplace=True)
tesla_data.to_csv('tesla_data.csv', index=False)
print(tesla_data.head())
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#    Adj Close     Volume
# 0   1.592667  281494500
# 1   1.588667  257806500
# 2   1.464000  123282000
# 3   1.280000   77097000
# 4   1.074000  103003500

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, "html.parser")
table = soup.find("table", class_="historical_data_table")
tesla_revenue = pd.read_html(str(table))[0]
print(tesla_revenue.tail())
# Out:
#     Tesla Annual Revenue (Millions of US $)  \
# 9                                      2013
# 10                                     2012
# 11                                     2011
# 12                                     2010
# 13                                     2009
#
#    Tesla Annual Revenue (Millions of US $).1
# 9                                     $2,013
# 10                                      $413
# 11                                      $204
# 12                                      $117
# 13                                      $112

# %%
gme_data = yf.download("GME")
gme_data.reset_index(inplace=True)
gme_data.to_csv('gme_data.csv', index=False)
print(gme_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#                        Date     Open     High      Low    Close  Adj Close  \
# 0 2002-02-13 00:00:00-05:00  2.40625  2.51500  2.38125  2.51250   1.691666
# 1 2002-02-14 00:00:00-05:00  2.54375  2.54875  2.48125  2.50000   1.683250
# 2 2002-02-15 00:00:00-05:00  2.50000  2.50625  2.46250  2.48750   1.674834
# 3 2002-02-19 00:00:00-05:00  2.47500  2.47500  2.34375  2.38750   1.607504
# 4 2002-02-20 00:00:00-05:00  2.40000  2.46875  2.38125  2.46875   1.662210
#
#      Volume
# 0  76216000
# 1  11021600
# 2   8389600
# 3   7410400
# 4   6892800

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup



url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"

response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
table = soup.find("table", class_="historical_data_table")
gme_revenue = pd.read_html(str(table))[0]
print(gme_revenue.tail())
# Out:
#     GameStop Annual Revenue (Millions of US $)  \
# 10                                        2013
# 11                                        2012
# 12                                        2011
# 13                                        2010
# 14                                        2009
#
#    GameStop Annual Revenue (Millions of US $).1
# 10                                       $8,887
# 11                                       $9,551
# 12                                       $9,474
# 13                                       $9,078
# 14                                       $8,806

# %%
import matplotlib.pyplot as plt
def make_graph(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['Date'], data['Close'])
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.title(title)
    plt.grid(True)
    plt.show()
tesla_data = pd.read_csv('tesla_data.csv')
make_graph(tesla_data, 'Tesla Stock Data')

# %%
import matplotlib.pyplot as plt
def make_graph(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['Date'], data['Close'])
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.title(title)
    plt.grid(True)
    plt.show()
gme_data = pd.read_csv('gme_data.csv')
make_graph(gme_data, 'GameStop Stock Data')
